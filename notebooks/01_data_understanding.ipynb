# %% [markdown]
# # 01 - Data Understanding
#
# In this notebook, we explore and understand the SMS Spam Collection dataset.

# %%
# Step 1: Import Pandas
import pandas as pd

# %% [markdown]
# ### Step 2: Load the Dataset
# Load the SMS Spam Collection dataset stored locally in `data/spam.csv`.

# %%
# Load dataset with latin-1 encoding
data = pd.read_csv("../data/spam.csv", encoding="latin-1")

# %% [markdown]
# ### Step 3: Display First Few Rows
# Preview the raw data.

# %%
data.head()

# %% [markdown]
# ### Step 4: Rename Columns for Readability
# Columns `v1` and `v2` are non-descriptive. We rename them to `label` and `message` to make our code self-documenting and easy to maintain.

# %%
# Rename v1 -> label, v2 -> message
data = data.rename(columns={"v1": "label", "v2": "message"})

# Display updated columns
data.head()
